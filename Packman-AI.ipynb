# %%
import random
import numpy as np
import pygame
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Board

# %%
main_board = [
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'A', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'W'],
    ['W', 'D', 'W', 'W', 'W', 'D', 'W', 'W', 'W', 'D', 'W'],
    ['W', 'D', 'W', 'D', 'D', 'D', 'D', 'D', 'W', 'D', 'W'],
    ['W', 'D', 'D', 'D', 'W', 'E', 'W', 'D', 'D', 'D', 'W'],
    ['W', 'D', 'W', 'D', 'W', 'E', 'W', 'D', 'W', 'D', 'W'],
    ['W', 'D', 'W', 'D', 'D', 'W', 'D', 'D', 'W', 'D', 'W'],
    ['W', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'W'],
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W']
]
board_rows = 7
board_cols = 9

# %% [markdown]
# ## Visualize

# %% [markdown]
# This 2 functions display the board and its changes during ruuning time

# %%
WIDTH, HEIGHT = 45, 45
WHITE = (255, 255, 255)
BLUE = (0, 0, 255)
YELLOW = (255, 255, 0)

def display_board(screen, map_data):
    for y, row in enumerate(map_data):
        for x, cell in enumerate(row):
            rect = pygame.Rect(x * WIDTH, y * HEIGHT, WIDTH, HEIGHT)
            if cell == 'W':
                pygame.draw.rect(screen, BLUE, rect)
            elif cell == 'A':
                pygame.draw.rect(screen, YELLOW, rect)
            elif cell == 'D':
                pygame.draw.circle(screen, WHITE, (x * WIDTH + WIDTH // 2, y * HEIGHT + HEIGHT // 2), 5)

def display_movements(map_data, reward):
    WIDTH, HEIGHT = 45, 45
    WHITE = (255, 255, 255)
    BLUE = (0, 0, 255)
    YELLOW = (255, 255, 0)
    
    window_size = (WIDTH * map_data.shape[1], HEIGHT * map_data.shape[0])
    screen = pygame.display.set_mode(window_size)
    screen.fill((0, 0, 0))
    
    
    pygame.display.set_caption("Pac-Man Game")

    display_board(screen, main_board)

    
    pygame.display.flip()
    pygame.display.update()
    pygame.time.delay(100)

# %% [markdown]
# ## Make Q-table

# %% [markdown]
# As we considered 3*3 blocks around agent and 3 possible amouts E, W, and D are there, Q-table has $3^8$ rows and $4$ columns.

# %%
Q_rows = 3 ** 8
Q_cols = 4
#initialize Q-table
Q = np.zeros((Q_rows, Q_cols))

# %% [markdown]
# ## Q-function

# %% [markdown]
# Define Q-function based on its definition

# %%
def Q_function(q, q_max, r, board, alpha = .5, gamma = .5, verbose = 0):
    return ((q + alpha * (r + gamma * q_max - q)))

# %% [markdown]
# ## Hash function

# %% [markdown]
# A function for mapping each state to a row in Q-table. This function converts states to 3-based numbers and map them to the Q-table rows.</br>
# it is a sparse matrix and some of its rows(states) could be omitted(as asked in the 1st parth of the question.)
# e.g. states which up, left, down, and right of the agent are W, could be omitted from the Q-table to reduce the states.

# %%
def hash_function(row, col, board):
    # E -> 0, W -> 1, D -> 2
    # 0 1 2
    # 3 X 4
    # 5 6 7
    matrix = [
        [0, 1, 2],
        [3, 0, 4],
        [5, 6, 7]
    ]
    hash_value = 0
    for i in range(3):
        for j in range(3):
            if i != 1 or j != 1:
                char = board[row + i - 1][col + j - 1]
                if char == 'E':
                    hash_value += 0 * 3**(matrix[i][j])
                elif char == 'W':
                    hash_value += 1 * 3**(matrix[i][j])
                elif char == 'D':
                    hash_value += 2 * 3**(matrix[i][j])
    return hash_value

# %%
# a map between hash and state
def get_state(row, col, board):
    return hash_function(row, col, board)

# %% [markdown]
# ## Reward

# %% [markdown]
# Each action has a reward; -2 for wall, -1 for empty, and 5 for dot.

# %%
def get_reward(new_state):
    if new_state == 'W':
        return -2
    elif new_state == 'E':
        return -1
    elif new_state == 'D':
        return 5

# %% [markdown]
# ## Find indices

# %% [markdown]
# This function walks through an state and finds the indices of its maximum values.

# %%
def find_indices(row, col, state, max_value, board):
    inds = []
    for ind, i in enumerate(state):
        if i == max_value:
            inds.append(ind)
    return inds

# %% [markdown]
# ## Get action Train

# %% [markdown]
# This is a function which finds the indices of max values in a state and with probability epsilon, chooses a random action and with probability (1 - epsilon) chooses an action with max Q-vlaue.

# %%
# 0 -> U
# 1 -> R
# 2 -> D
# 3 -> L
def get_action(row, col, state, board, epsilon):
    
    max_value = max(Q[state])
    max_value_indices = find_indices(row, col, Q[state], max_value, board)
    no_max_values = len(max_value_indices)

    choice = random.random()
    
    # choose a max value
    if choice > epsilon:
        return int(random.choice(max_value_indices))
    # choose a random action
    else:
        return random.randint(0, 3)

# %% [markdown]
# ## Packman

# %% [markdown]
# in this section, we try to walk through the map and collect all dots. in each iteration, while there are dots in the board, choose and action, move if it is possible, copmute the new Q-value and update the current state and continue.

# %%
import random
def Packman(board, epsilon, verbose=0):
    row = 1
    col = 1
    # count dots in a 2d list
    dots = 0
    for i in range(1, board_rows + 1):
        dots += board[i].count('D')
    
    current_state = get_state(row, col, board)

    while dots > 0:
        
        if verbose > 1: print(f"{row} {col} dots: {dots}", end = ' ')
    
        action = get_action(row, col, current_state, board, epsilon)
        
        reward = 0
        i, j = 0, 0
        if action == 0: # U
            if board[row - 1][col] != 'W': # if the up block is not a wall, move
                board[row][col] = 'E'
                i -= 1
                reward = get_reward(board[row-1][col])
                if verbose > 1: print('U')

        elif action == 1: # R
            if board[row][col + 1] != 'W':
                board[row][col] = 'E'
                j += 1
                reward = get_reward(board[row][col+1])
                if verbose > 1: print('R')

        elif action == 2: # D
            if board[row + 1][col] != 'W':
                board[row][col] = 'E'
                i += 1
                reward = get_reward(board[row+1][col])
                if verbose > 1: print('D')


        elif action == 3: # L
            if board[row][col - 1] != 'W':
                board[row][col] = 'E'
                j -= 1
                reward = get_reward(board[row][col-1])
                if verbose > 1: print('L')
        row += i
        col += j
        
        new_state = current_state
        if board[row][col] == 'D':
            dots -= 1
        if board[row][col] == 'D' or board[row][col] == 'E':
            board[row][col] = 'A'
            new_state = get_state(row, col, board)
            
        elif board[row][col] == 'W':
            reward = get_reward(board[row][col])
            row -= i
            col -= j
            
        

        if dots == 0:
            break
        
        Q[current_state][action] = Q_function(Q[current_state][action], max(Q[new_state]), reward, board, verbose=verbose) # is it right?
        current_state = new_state

# %% [markdown]
# # Train

# %% [markdown]
# In this section, training is happening. with initial epsilon 0.9, we try to train out model in 200 episodes. each time we have to decrease epsilon as it is the rate of choosing randomly in the traning time.

# %%
import time

epsilon = 0.9
rounds  = 200

start = time.time()
for i in range(rounds):
    instance = []
    for j in main_board:
        instance.append(j.copy())
#     print("difed")    
#     print("fff")
    Packman(instance, epsilon)
    epsilon *= (5/9) ** (1/40)
    print(f"{i} iteration")

end = time.time()
print(end - start)
# Out:
# 0 iteration
# 1 iteration
# 2 iteration
# 3 iteration
# 4 iteration
# 5 iteration
# 6 iteration
# 7 iteration
# 8 iteration
# 9 iteration
# 10 iteration
# 11 iteration
# 12 iteration
# 13 iteration
# 14 iteration
# 15 iteration
# 16 iteration
# 17 iteration
# 18 iteration
# 19 iteration
# 20 iteration
# 21 iteration
# 22 iteration
# 23 iteration
# 24 iteration
# 25 iteration
# 26 iteration
# 27 iteration
# 28 iteration
# 29 iteration
# 30 iteration
# 31 iteration
# 32 iteration
# 33 iteration
# 34 iteration
# 35 iteration
# 36 iteration
# 37 iteration
# 38 iteration
# 39 iteration
# 40 iteration
# 41 iteration
# 42 iteration
# 43 iteration
# 44 iteration
# 45 iteration
# 46 iteration
# 47 iteration
# 48 iteration
# 49 iteration
# 50 iteration
# 51 iteration
# 52 iteration
# 53 iteration
# 54 iteration
# 55 iteration
# 56 iteration
# 57 iteration
# 58 iteration
# 59 iteration
# 60 iteration
# 61 iteration
# 62 iteration
# 63 iteration
# 64 iteration
# 65 iteration
# 66 iteration
# 67 iteration
# 68 iteration
# 69 iteration
# 70 iteration
# 71 iteration
# 72 iteration
# 73 iteration
# 74 iteration
# 75 iteration
# 76 iteration
# 77 iteration
# 78 iteration
# 79 iteration
# 80 iteration
# 81 iteration
# 82 iteration
# 83 iteration
# 84 iteration
# 85 iteration
# 86 iteration
# 87 iteration
# 88 iteration
# 89 iteration
# 90 iteration
# 91 iteration
# 92 iteration
# 93 iteration
# 94 iteration
# 95 iteration
# 96 iteration
# 97 iteration
# 98 iteration
# 99 iteration
# 100 iteration
# 101 iteration
# 102 iteration
# 103 iteration
# 104 iteration
# 105 iteration
# 106 iteration
# 107 iteration
# 108 iteration
# 109 iteration
# 110 iteration
# 111 iteration
# 112 iteration
# 113 iteration
# 114 iteration
# 115 iteration
# 116 iteration
# 117 iteration
# 118 iteration
# 119 iteration
# 120 iteration
# 121 iteration
# 122 iteration
# 123 iteration
# 124 iteration
# 125 iteration
# 126 iteration
# 127 iteration
# 128 iteration
# 129 iteration
# 130 iteration
# 131 iteration
# 132 iteration
# 133 iteration
# 134 iteration
# 135 iteration
# 136 iteration
# 137 iteration
# 138 iteration
# 139 iteration
# 140 iteration
# 141 iteration
# 142 iteration
# 143 iteration
# 144 iteration
# 145 iteration
# 146 iteration
# 147 iteration
# 148 iteration
# 149 iteration
# 150 iteration
# 151 iteration
# 152 iteration
# 153 iteration
# 154 iteration
# 155 iteration
# 156 iteration
# 157 iteration
# 158 iteration
# 159 iteration
# 160 iteration
# 161 iteration
# 162 iteration
# 163 iteration
# 164 iteration
# 165 iteration
# 166 iteration
# 167 iteration
# 168 iteration
# 169 iteration
# 170 iteration
# 171 iteration
# 172 iteration
# 173 iteration
# 174 iteration
# 175 iteration
# 176 iteration
# 177 iteration
# 178 iteration
# 179 iteration
# 180 iteration
# 181 iteration
# 182 iteration
# 183 iteration
# 184 iteration
# 185 iteration
# 186 iteration
# 187 iteration
# 188 iteration
# 189 iteration
# 190 iteration
# 191 iteration
# 192 iteration
# 193 iteration
# 194 iteration
# 195 iteration
# 196 iteration
# 197 iteration
# 198 iteration
# 199 iteration
# 1.027876853942871

# %% [markdown]
# Print non-zero rows of Q-table as it is asked in the question.

# %%
for i in Q:
    flag = False
    for j in i:
        if j!= 0:
            flag = True
    if flag : print(i)
# Out:
# [ 0.         -0.88257534 -1.          0.        ]
# [-1. -1. -1.  0.]
# [ 9.24881584 -0.61024669 -0.84240823  3.31372954]
# [ 1.45961266e-03  2.50557744e+00 -5.92458574e-01  4.86537552e-04]
# [ 0.  0. -1. -1.]
# [ 0.          0.55235732 -0.99169049  1.50159061]
# [-9.99999990e-001  4.00129104e-199 -1.00000000e+000 -9.96234894e-001]
# [ 5.00001759  4.00534885 -0.49999556  0.10559219]
# [-1.          0.         -1.49977683  0.        ]
# [ 3.8429786   1.235866   -1.20038661  1.88208404]
# [ 2.93447181  0.         -0.94277748  0.        ]
# [ 2.99875193  0.         -0.73870826  0.        ]
# [ 0.          0.         -1.31228638  0.        ]
# [ 9.92789345  3.62553373 -1.43995734  4.69301621]
# [ 3.7139181   1.97077019 -0.26270473  8.00757098]
# [ 0.2234812   1.2487793  -0.03749368  4.99998093]
# [8.1080962 0.        0.        0.       ]
# [ 0.          2.5        -0.25390625  0.        ]
# [-0.25003186  5.         -0.08218365  2.41735129]
# [5.89904563 5.36697937 0.18617138 2.50372119]
# [ 2.97803317  7.5001496  -0.17117747  3.38667902]
# [ 1.16625479e-121  1.23114717e-121 -1.00000000e+000 -2.30306098e-001]
# [-1.0e+000  1.5e-323 -1.0e+000  1.5e-323]
# [ 5.09550861e-001  1.48219694e-323 -1.00000000e+000  1.48219694e-323]
# [ 1.82512455  0.00791552 -0.99609375  0.        ]
# [ 0.   0.  -0.5  0. ]
# [ 5.65540154  3.6596501  -0.76282381  3.07307742]
# [ 8.49732371  2.22037682 -0.9375      4.05672932]
# [2.97959888 3.31668259 0.03722389 5.00000433]
# [ 0.         -0.5         2.46823176  0.        ]
# [0.       0.       1.359375 0.      ]
# [0.         0.         3.88172802 1.24789972]
# [0.         0.         0.         1.83523039]
# [ 0.          0.          2.31349681 -0.875     ]
# [-0.5        0.         2.2148986 -0.75     ]
# [ 2.5   0.    0.   -0.75]
# [-0.75        0.          2.37628586  0.79504313]
# [ 0.   0.  -0.5  0. ]
# [0.         0.         1.40673828 0.        ]
# [ 0.          0.         -0.25537109  0.        ]
# [ 1.46484375  1.41601562 -0.58691406  9.40580096]
# [0.  0.  0.  2.5]
# [0.         0.625      0.         5.60001972]
# [0.        0.        1.5032418 0.       ]
# [2.94675095 5.78991019 0.         0.        ]
# [0.         0.         3.01292605 0.        ]
# [ 0.         -1.          0.         -0.99995745]
# [ 8.73304378e-67 -1.49993486e+00  7.79602317e-67 -9.80143682e-01]
# [ 0.82746273 -0.90772647  1.05925703  2.61396336]
# [ 8.62256089e-105 -9.99822800e-001  1.08033934e-104 -1.36672910e+000]
# [ 0.15625    -0.98065186  0.15625     3.10060044]
# [ 1.91191861  3.99246972  1.73711742 -0.9965944 ]
# [ 1.16567964  2.91830804  0.44458008 -0.84349585]
# [ 0.   0.   0.  -0.5]
# [ 0.          3.86808865  0.         -0.5       ]
# [4.95444653 3.83540697 3.37252853 9.99292635]
# [-0.66130465  0.05612752  0.          0.        ]
# [4.81730773 9.93427753 4.93288764 3.40798001]
# [0.         0.         7.35822814 0.        ]
# [ 0.          1.17521986  8.89120818 -0.17708962]
# [ 0.          0.          7.37351988 -0.125     ]
# [-0.5         1.86013871  9.70805412  0.        ]
# [7.06788667 0.         7.43118737 0.        ]
# [1.97065496 0.         0.         0.        ]
# [-0.04137793  0.          0.          3.10551834]
# [0.    0.    3.125 0.   ]
# [ 4.87371345  4.47686916  9.9538322  -0.3112797 ]
# [-0.21362305  3.90453362  7.55918802  3.79737271]
# [0.89268642 4.98262632 9.99099208 4.97922871]
# [-0.71875     2.6342852   8.8762596   3.11205519]
# [4.95880007 2.27950632 9.80133774 4.80813893]
# [0.         0.         4.42871094 0.        ]
# [ 0.          0.          6.73965692 -0.5       ]
# [-0.75        0.          8.09128382  2.9617153 ]
# [-0.74955197  3.97500038  9.36372662  2.73381233]
# [2.77534447 0.69383612 4.70855493 0.        ]
# [2.08941306 2.77905671 9.35706156 1.35742188]
# [0.20007845 4.91111235 9.56587579 9.95647088]
# [-0.61001897  5.39327811  9.92344308  3.67834616]

# %% [markdown]
# This function is for choosing action in testing time.
# It always chooses max values among all possible actions.

# %%
def get_action_test(row, col, state, board):
        
    max_value = max(Q[state])
    max_value_indices = find_indices(row, col, Q[state], max_value, board)
    no_max_values = len(max_value_indices)
# ----------------------------------------------------
#     choice = random.random()
#     if choice < .1:
#         return random.randint(0, 3)
# ----------------------------------------------------

    return random.choice(max_value_indices)

# %% [markdown]
# this function also handles the testing part, choosing action, moving, and going to the next state

# %%
def test_Packman(board, dots, verbose=2):
    row = 1
    col = 1

    pre = 0
    cnt = 0
    
    total_reward = 0
    
    current_state = get_state(row, col, board)
    iteration = 0
    action = None
    pygame.init()
    display_movements(board, total_reward)
    while dots > 0:
        print("total reward: ", total_reward)
        if verbose > 1: print(f"{row} {col} dots: {dots}", end = ' ')
        
        if cnt > 5:
            action = random.randint(0, 3)
            cnt = 0
        else:
            action = get_action_test(row, col, current_state, board)
        
        i,j = 0, 0
        if action == 0: # U
            if board[row - 1][col] != 'W':
                board[row][col] = 'E'
                i -= 1
                if verbose > 1: print('U')

        elif action == 1: # R
            if board[row][col + 1] != 'W':
                board[row][col] = 'E'
                j += 1

                if verbose > 1: print('R')

        elif action == 2: # D
            if board[row + 1][col] != 'W':
                board[row][col] = 'E'
                i += 1
                if verbose > 1: print('D')

        elif action == 3: # L
            if board[row][col - 1] != 'W':
                board[row][col] = 'E'
                j -= 1
                if verbose > 1: print('L')
        
        row += i
        col += j
        
        if board[row][col] == 'D':
            total_reward += 5
            dots -= 1
            cnt = 0
            board[row][col] = 'A'
        elif board[row][col] == 'E':
            total_reward -= 1
            board[row][col] = 'A'
        if board[row][col] != 'D':
            cnt += 1

        

        iteration += 1
        
        print("iterations: ", iteration)
        print('-' * 60)
    
        
        current_state = get_state(row, col, board)
        pre = current_state
        
        display_movements(board, total_reward)
    pygame.quit()

# %% [markdown]
# Test the code with the main board: it took 54 iterations to eat all 43 dots!

# %%
test_1 = []
dots = 0
for row in main_board:
    dots += row.count('D')
    test_1.append(row.copy())
test_Packman(np.array(test_1), dots)
# Out:
# total reward:  0
# 1 1 dots: 43 D
# iterations:  1
# ------------------------------------------------------------
# total reward:  5
# 2 1 dots: 42 D
# iterations:  2
# ------------------------------------------------------------
# total reward:  10
# 3 1 dots: 41 D
# iterations:  3
# ------------------------------------------------------------
# total reward:  15
# 4 1 dots: 40 D
# iterations:  4
# ------------------------------------------------------------
# total reward:  20
# 5 1 dots: 39 D
# iterations:  5
# ------------------------------------------------------------
# total reward:  25
# 6 1 dots: 38 D
# iterations:  6
# ------------------------------------------------------------
# total reward:  30
# 7 1 dots: 37 R
# iterations:  7
# ------------------------------------------------------------
# total reward:  35
# 7 2 dots: 36 R
# iterations:  8
# ------------------------------------------------------------
# total reward:  40
# 7 3 dots: 35 R
# iterations:  9
# ------------------------------------------------------------
# total reward:  45
# 7 4 dots: 34 U
# iterations:  10
# ------------------------------------------------------------
# total reward:  50
# 6 4 dots: 33 L
# iterations:  11
# ------------------------------------------------------------
# total reward:  55
# 6 3 dots: 32 U
# iterations:  12
# ------------------------------------------------------------
# total reward:  60
# 5 3 dots: 31 U
# iterations:  13
# ------------------------------------------------------------
# total reward:  65
# 4 3 dots: 30 L
# iterations:  14
# ------------------------------------------------------------
# total reward:  70
# 4 2 dots: 29 R
# iterations:  15
# ------------------------------------------------------------
# total reward:  69
# 4 3 dots: 29 U
# iterations:  16
# ------------------------------------------------------------
# total reward:  74
# 3 3 dots: 28 R
# iterations:  17
# ------------------------------------------------------------
# total reward:  79
# 3 4 dots: 27 R
# iterations:  18
# ------------------------------------------------------------
# total reward:  84
# 3 5 dots: 26 R
# iterations:  19
# ------------------------------------------------------------
# total reward:  89
# 3 6 dots: 25 R
# iterations:  20
# ------------------------------------------------------------
# total reward:  94
# 3 7 dots: 24 D
# iterations:  21
# ------------------------------------------------------------
# total reward:  99
# 4 7 dots: 23 R
# iterations:  22
# ------------------------------------------------------------
# total reward:  104
# 4 8 dots: 22 R
# iterations:  23
# ------------------------------------------------------------
# total reward:  109
# 4 9 dots: 21 D
# iterations:  24
# ------------------------------------------------------------
# total reward:  114
# 5 9 dots: 20 D
# iterations:  25
# ------------------------------------------------------------
# total reward:  119
# 6 9 dots: 19 D
# iterations:  26
# ------------------------------------------------------------
# total reward:  124
# 7 9 dots: 18 L
# iterations:  27
# ------------------------------------------------------------
# total reward:  129
# 7 8 dots: 17 L
# iterations:  28
# ------------------------------------------------------------
# total reward:  134
# 7 7 dots: 16 L
# iterations:  29
# ------------------------------------------------------------
# total reward:  139
# 7 6 dots: 15 L
# iterations:  30
# ------------------------------------------------------------
# total reward:  144
# 7 5 dots: 14 R
# iterations:  31
# ------------------------------------------------------------
# total reward:  143
# 7 6 dots: 14 U
# iterations:  32
# ------------------------------------------------------------
# total reward:  148
# 6 6 dots: 13 R
# iterations:  33
# ------------------------------------------------------------
# total reward:  153
# 6 7 dots: 12 U
# iterations:  34
# ------------------------------------------------------------
# total reward:  158
# 5 7 dots: 11 iterations:  35
# ------------------------------------------------------------
# total reward:  158
# 5 7 dots: 11 iterations:  36
# ------------------------------------------------------------
# total reward:  158
# 5 7 dots: 11 iterations:  37
# ------------------------------------------------------------
# total reward:  158
# 5 7 dots: 11 iterations:  38
# ------------------------------------------------------------
# total reward:  158
# 5 7 dots: 11 iterations:  39
# ------------------------------------------------------------
# total reward:  158
# 5 7 dots: 11 U
# iterations:  40
# ------------------------------------------------------------
# total reward:  157
# 4 7 dots: 11 R
# iterations:  41
# ------------------------------------------------------------
# total reward:  156
# 4 8 dots: 11 R
# iterations:  42
# ------------------------------------------------------------
# total reward:  155
# 4 9 dots: 11 U
# iterations:  43
# ------------------------------------------------------------
# total reward:  160
# 3 9 dots: 10 U
# iterations:  44
# ------------------------------------------------------------
# total reward:  165
# 2 9 dots: 9 U
# iterations:  45
# ------------------------------------------------------------
# total reward:  170
# 1 9 dots: 8 L
# iterations:  46
# ------------------------------------------------------------
# total reward:  175
# 1 8 dots: 7 L
# iterations:  47
# ------------------------------------------------------------
# total reward:  180
# 1 7 dots: 6 L
# iterations:  48
# ------------------------------------------------------------
# total reward:  185
# 1 6 dots: 5 L
# iterations:  49
# ------------------------------------------------------------
# total reward:  190
# 1 5 dots: 4 D
# iterations:  50
# ------------------------------------------------------------
# total reward:  195
# 2 5 dots: 3 U
# iterations:  51
# ------------------------------------------------------------
# total reward:  194
# 1 5 dots: 3 L
# iterations:  52
# ------------------------------------------------------------
# total reward:  199
# 1 4 dots: 2 L
# iterations:  53
# ------------------------------------------------------------
# total reward:  204
# 1 3 dots: 1 L
# iterations:  54
# ------------------------------------------------------------

# %% [markdown]
# take another board for testing the model

# %%
board_4 = [
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W'],
    ['W', 'A', 'D', 'D', 'D', 'D', 'D', 'W'],
    ['W', 'D', 'W', 'W', 'D', 'W', 'D', 'W'],
    ['W', 'D', 'W', 'D', 'D', 'D', 'D', 'W'],
    ['W', 'D', 'W', 'W', 'E', 'W', 'D', 'W'],
    ['W', 'D', 'D', 'D', 'D', 'D', 'D', 'W'],
    ['W', 'W', 'W', 'W', 'W', 'W', 'W', 'W']
]

test_4 = []
dot_4 = 0
for i in board_4:
    dot_4 += i.count('D')
    test_4.append(i.copy())
print("here: ", dot_4)
test_Packman(np.array(test_4), dot_4)
# Out:
# here:  21
# total reward:  0
# 1 1 dots: 21 D
# iterations:  1
# ------------------------------------------------------------
# total reward:  5
# 2 1 dots: 20 D
# iterations:  2
# ------------------------------------------------------------
# total reward:  10
# 3 1 dots: 19 D
# iterations:  3
# ------------------------------------------------------------
# total reward:  15
# 4 1 dots: 18 D
# iterations:  4
# ------------------------------------------------------------
# total reward:  20
# 5 1 dots: 17 R
# iterations:  5
# ------------------------------------------------------------
# total reward:  25
# 5 2 dots: 16 iterations:  6
# ------------------------------------------------------------
# total reward:  25
# 5 2 dots: 16 iterations:  7
# ------------------------------------------------------------
# total reward:  25
# 5 2 dots: 16 L
# iterations:  8
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  9
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  10
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  11
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  12
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  13
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  14
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  15
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  16
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  17
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  18
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  19
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  20
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  21
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  22
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  23
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  24
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  25
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  26
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  27
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 iterations:  28
# ------------------------------------------------------------
# total reward:  24
# 5 1 dots: 16 U
# iterations:  29
# ------------------------------------------------------------
# total reward:  23
# 4 1 dots: 16 U
# iterations:  30
# ------------------------------------------------------------
# total reward:  22
# 3 1 dots: 16 D
# iterations:  31
# ------------------------------------------------------------
# total reward:  21
# 4 1 dots: 16 U
# iterations:  32
# ------------------------------------------------------------
# total reward:  20
# 3 1 dots: 16 U
# iterations:  33
# ------------------------------------------------------------
# total reward:  19
# 2 1 dots: 16 U
# iterations:  34
# ------------------------------------------------------------
# total reward:  18
# 1 1 dots: 16 D
# iterations:  35
# ------------------------------------------------------------
# total reward:  17
# 2 1 dots: 16 U
# iterations:  36
# ------------------------------------------------------------
# total reward:  16
# 1 1 dots: 16 R
# iterations:  37
# ------------------------------------------------------------
# total reward:  21
# 1 2 dots: 15 R
# iterations:  38
# ------------------------------------------------------------
# total reward:  26
# 1 3 dots: 14 R
# iterations:  39
# ------------------------------------------------------------
# total reward:  31
# 1 4 dots: 13 R
# iterations:  40
# ------------------------------------------------------------
# total reward:  36
# 1 5 dots: 12 iterations:  41
# ------------------------------------------------------------
# total reward:  36
# 1 5 dots: 12 iterations:  42
# ------------------------------------------------------------
# total reward:  36
# 1 5 dots: 12 L
# iterations:  43
# ------------------------------------------------------------
# total reward:  35
# 1 4 dots: 12 D
# iterations:  44
# ------------------------------------------------------------
# total reward:  40
# 2 4 dots: 11 D
# iterations:  45
# ------------------------------------------------------------
# total reward:  45
# 3 4 dots: 10 R
# iterations:  46
# ------------------------------------------------------------
# total reward:  50
# 3 5 dots: 9 R
# iterations:  47
# ------------------------------------------------------------
# total reward:  55
# 3 6 dots: 8 D
# iterations:  48
# ------------------------------------------------------------
# total reward:  60
# 4 6 dots: 7 iterations:  49
# ------------------------------------------------------------
# total reward:  60
# 4 6 dots: 7 D
# iterations:  50
# ------------------------------------------------------------
# total reward:  65
# 5 6 dots: 6 L
# iterations:  51
# ------------------------------------------------------------
# total reward:  70
# 5 5 dots: 5 L
# iterations:  52
# ------------------------------------------------------------
# total reward:  75
# 5 4 dots: 4 L
# iterations:  53
# ------------------------------------------------------------
# total reward:  80
# 5 3 dots: 3 iterations:  54
# ------------------------------------------------------------
# total reward:  80
# 5 3 dots: 3 R
# iterations:  55
# ------------------------------------------------------------
# total reward:  79
# 5 4 dots: 3 U
# iterations:  56
# ------------------------------------------------------------
# total reward:  78
# 4 4 dots: 3 U
# iterations:  57
# ------------------------------------------------------------
# total reward:  77
# 3 4 dots: 3 L
# iterations:  58
# ------------------------------------------------------------
# total reward:  82
# 3 3 dots: 2 R
# iterations:  59
# ------------------------------------------------------------
# total reward:  81
# 3 4 dots: 2 U
# iterations:  60
# ------------------------------------------------------------
# total reward:  80
# 2 4 dots: 2 iterations:  61
# ------------------------------------------------------------
# total reward:  80
# 2 4 dots: 2 iterations:  62
# ------------------------------------------------------------
# total reward:  80
# 2 4 dots: 2 iterations:  63
# ------------------------------------------------------------
# total reward:  80
# 2 4 dots: 2 iterations:  64
# ------------------------------------------------------------
# total reward:  80
# 2 4 dots: 2 iterations:  65
# ------------------------------------------------------------
# total reward:  80
# 2 4 dots: 2 iterations:  66
# ------------------------------------------------------------
# total reward:  80
# 2 4 dots: 2 iterations:  67
# ------------------------------------------------------------
# total reward:  80
# 2 4 dots: 2 iterations:  68
# ------------------------------------------------------------
# total reward:  80
# 2 4 dots: 2 iterations:  69
# ------------------------------------------------------------
# total reward:  80
# 2 4 dots: 2 U
# iterations:  70
# ------------------------------------------------------------
# total reward:  79
# 1 4 dots: 2 R
# iterations:  71
# ------------------------------------------------------------
# total reward:  78
# 1 5 dots: 2 R
# iterations:  72
# ------------------------------------------------------------
# total reward:  83
# 1 6 dots: 1 D
# iterations:  73
# ------------------------------------------------------------
